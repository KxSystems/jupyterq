# %%
\l htmltable.q

# %% [markdown]
# Define a long table

# %%
lastprice:([sym:100000?`IBM`MSFT`AAPL`GOOG;exch:100000?`A`B`C]time:asc 100000?.z.p;price:10f+100000?10f;size:100*1+100000?10)

# %% [markdown]
# Display as html table

# %%
maxcols:6
maxrows:20
displayhtmltab[maxrows;maxcols]lastprice
# Out:
# <style >
# col.key {
# 	background-color:#ccffff;
# }
# col.val {
# 	background-color:#ffffcc;
# 	foreground-color:red;
# }
# </style>
# <table >
# <colgroup >
# <col span="2" class="key"/>
# <col span="3" class="val"/>
# </colgroup>
# <thead >
# <th >
# sym
# </th>
# <th >
# exch
# </th>
# <th >
# time
# </th>
# <th >
# price
# </th>
# <th >
# size
# </th>
# </thead>
# <tbody >
# <tr >
# <td >
# `MSFT
# </td>
# <td >
# `C
# </td>
# <td >
# 2000.01.01D00:23:34.972602912
# </td>
# <td >
# 11.58824
# </td>
# <td >
# 900
# </td>
# </tr>
# <tr >
# <td >
# `AAPL
# </td>
# <td >
# `C
# </td>
# <td >
# 2000.01.01D01:41:29.023671807
# </td>
# <td >
# 13.56016
# </td>
# <td >
# 200
# </td>
# </tr>
# <tr >
# <td >
# `GOOG
# </td>
# <td >
# `A
# </td>
# <td >
# 2000.01.01D02:23:22.343989602
# </td>
# <td >
# 11.57379
# </td>
# <td >
# 1000
# </td>
# </tr>
# <tr >
# <td >
# `MSFT
# </td>
# <td >
# `B
# </td>
# <td >
# 2000.01.01D04:28:08.968645948
# </td>
# <td >
# 13.50636
# </td>
# <td >
# ...
